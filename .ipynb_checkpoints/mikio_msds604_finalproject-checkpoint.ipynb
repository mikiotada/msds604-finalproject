# %%
#import necessary libraries 
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from statsmodels.tsa.arima_model import ARIMA
import pmdarima as pm

from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries):
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)

# %%
data = pd.read_csv('../zillow-carlifornia .csv', parse_dates=True, squeeze=True)
data.shape
# Out:
# (164, 5)

# %%
data.head(3)
# Out:
#          Date  MedianSoldPrice_AllHomes.California  MedianMortageRate  \
# 0  2004-01-31                            326752.55               5.02
# 1  2004-02-29                            329501.50               4.94
# 2  2004-03-31                            340125.45               4.74
#
#    UnemploymentRate  MedianRentalPrice_AllHomes.California
# 0               7.9                                    NaN
# 1               7.8                                    NaN
# 2               7.8                                    NaN

# %%
data.tail(25)
# Out:
#            Date  MedianSoldPrice_AllHomes.California  MedianMortageRate  \
# 139  2015-08-31                             426650.0               3.87
# 140  2015-09-30                             421750.0               3.80
# 141  2015-10-31                             417400.0               3.69
# 142  2015-11-30                             420450.0               3.89
# 143  2015-12-31                             421000.0               3.91
# 144  2016-01-31                                  NaN               3.96
# 145  2016-02-29                                  NaN               3.60
# 146  2016-03-31                                  NaN               3.60
# 147  2016-04-30                                  NaN               3.59
# 148  2016-05-31                                  NaN               3.59
# 149  2016-06-30                                  NaN               3.46
# 150  2016-07-31                                  NaN               3.46
# 151  2016-08-31                                  NaN               3.42
# 152  2016-09-30                                  NaN               3.36
# 153  2016-10-31                                  NaN               3.47
# 154  2016-11-30                                  NaN               4.07
# 155  2016-12-31                                  NaN               4.21
# 156  2017-01-31                                  NaN               4.07
# 157  2017-02-28                                  NaN               3.93
# 158  2017-03-31                                  NaN               4.00
# 159  2017-04-30                                  NaN               3.91
# 160  2017-05-31                                  NaN               3.83
# 161  2017-06-30                                  NaN               3.88
# 162  2017-07-31                                  NaN               3.88
# 163  2017-08-31                                  NaN               3.74
#
#      UnemploymentRate  MedianRentalPrice_AllHomes.California
# 139               5.1                                 2300.0
# 140               5.0                                 2300.0
# 141               5.0                                 2300.0
# 142               5.1                                 2300.0
# 143               5.0                                 2300.0
# 144               4.9                                 2300.0
# 145               5.0                                 2350.0
# 146               5.0                                 2400.0
# 147               4.8                                 2395.0
# 148               4.8                                 2395.0
# 149               4.9                                 2395.0
# 150               4.8                                 2400.0
# 151               5.0                                 2390.0
# 152               5.0                                 2399.5
# 153               4.8                                 2350.0
# 154               4.7                                 2400.0
# 155               4.7                                 2300.0
# 156               4.7                                 2400.0
# 157               4.7                                 2500.0
# 158               4.4                                 2500.0
# 159               4.4                                 2600.0
# 160               4.3                                 2650.0
# 161               4.4                                 2675.0
# 162               4.3                                 2695.0
# 163               4.3                                 2695.0

# %%
target = data["MedianSoldPrice_AllHomes.California"]
plt.figure(figsize=(20,6))
plt.xticks(np.arange(0, 170, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016', '2017', '2018'))
plt.title("Line plot for Monthly Median Sold Price for Housing ($)")
pyplot.xlabel('Year')
pyplot.plot(target)
pyplot.show()

# %%
X = data['MedianSoldPrice_AllHomes.California'].dropna(); X
# Out:
# 0      326752.55
# 1      329501.50
# 2      340125.45
# 3      355329.50
# 4      367818.15
#          ...
# 139    426650.00
# 140    421750.00
# 141    417400.00
# 142    420450.00
# 143    421000.00
# Name: MedianSoldPrice_AllHomes.California, Length: 144, dtype: float64

# %%
#first differecing the trend
d1 = list()
for i in range(1, len(X)):
    value = X[i] - X[i - 1]
    d1.append(value)

plt.title('First differecing to eliminate the trend')
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(d1) 
pyplot.show()

adf_test(d1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -1.687305
# p-value                          0.437665
# #Lags Used                      12.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %%
#second differecing the trend
d2 = list()
for i in range(1, len(d1)):
    value = d1[i] - d1[i - 1]
    d2.append(value)

plt.title('Second differecing to eliminate the trend')
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(d2) 
pyplot.show()

adf_test(d2)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.918846
# p-value                          0.000032
# #Lags Used                      11.000000
# Number of Observations Used    130.000000
# Critical Value (1%)             -3.481682
# Critical Value (5%)             -2.884042
# Critical Value (10%)            -2.578770
# dtype: float64

# %%
#third differecing the trend
d3 = list()
for i in range(1, len(d2)):
    value = d2[i] - d2[i - 1]
    d3.append(value)

plt.title('third differecing to eliminate the trend')
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(d3) 
pyplot.show()

adf_test(d3)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.368268e+00
# p-value                        9.114125e-11
# #Lags Used                     1.400000e+01
# Number of Observations Used    1.260000e+02
# Critical Value (1%)           -3.483346e+00
# Critical Value (5%)           -2.884766e+00
# Critical Value (10%)          -2.579156e+00
# dtype: float64

# %%
#first differecing the seasonality with d=2
s1 = list()
for i in range(12, len(d2)):
    value = d2[i] - d2[i - 12]
    s1.append(value)

plt.title('Second differecing to eliminate the trend')
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(s1) 
pyplot.show()

adf_test(s1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -5.149454
# p-value                          0.000011
# #Lags Used                      13.000000
# Number of Observations Used    116.000000
# Critical Value (1%)             -3.488022
# Critical Value (5%)             -2.886797
# Critical Value (10%)            -2.580241
# dtype: float64

# %%
#first differecing the seasonality with d=3 
s1_1 = list()
for i in range(12, len(d3)):
    value = d3[i] - d3[i - 12]
    s1_1.append(value)

plt.title('Second differecing to eliminate the trend')
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(s1_1) 
pyplot.show()

adf_test(s1_1)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                  -4.783772
# p-value                          0.000058
# #Lags Used                      13.000000
# Number of Observations Used    115.000000
# Critical Value (1%)             -3.488535
# Critical Value (5%)             -2.887020
# Critical Value (10%)            -2.580360
# dtype: float64

# %%
#possible (2, 1, 12), (3, 1, 12), (2, 2, 12), (3, 2, 12)

# %%
train_size = int(len(X) * 0.8)
train, test = data['MedianSoldPrice_AllHomes.California'][0:train_size].dropna(), data['MedianSoldPrice_AllHomes.California'][train_size:].dropna()
forecast = data['MedianSoldPrice_AllHomes.California'][144:174]

# %%
plt.title("Training and test data")
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(train, label='training')
plt.plot(test, label='test')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
#(2, 1, 12)
model_1 = pm.auto_arima(train, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=2, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# print(model_1.summary())
fitted_1 = model_1.fit(train)
fc_1, conf_1 = fitted_1.predict(len(test),return_conf_int=True,alpha=0.05)
fc_series_1 = pd.Series(fc_1, index=test.index)
lower_series_1 = pd.Series(conf_1[:, 0], index=test.index)
upper_series_1 = pd.Series(conf_1[:, 1], index=test.index)
# Out:
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(0, 1, 1, 12); AIC=1997.725, BIC=2010.800, Fit time=0.735 seconds
# Fit ARIMA: order=(0, 2, 0) seasonal_order=(0, 1, 0, 12); AIC=2009.374, BIC=2014.604, Fit time=0.015 seconds
# Fit ARIMA: order=(1, 2, 0) seasonal_order=(1, 1, 0, 12); AIC=2013.021, BIC=2023.482, Fit time=0.150 seconds
# Fit ARIMA: order=(0, 2, 1) seasonal_order=(0, 1, 1, 12); AIC=2013.214, BIC=2023.674, Fit time=0.192 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(1, 1, 1, 12); AIC=1997.765, BIC=2013.456, Fit time=1.169 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(0, 1, 0, 12); AIC=1995.624, BIC=2006.084, Fit time=0.317 seconds
# Fit ARIMA: order=(0, 2, 1) seasonal_order=(0, 1, 0, 12); AIC=2011.389, BIC=2019.235, Fit time=0.038 seconds
# Fit ARIMA: order=(2, 2, 1) seasonal_order=(0, 1, 0, 12); AIC=1997.604, BIC=2010.679, Fit time=0.318 seconds
# Fit ARIMA: order=(1, 2, 0) seasonal_order=(0, 1, 0, 12); AIC=2011.192, BIC=2019.038, Fit time=0.031 seconds
# Fit ARIMA: order=(1, 2, 2) seasonal_order=(0, 1, 0, 12); AIC=1997.631, BIC=2010.706, Fit time=0.449 seconds
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(0, 1, 0, 12); AIC=1999.498, BIC=2015.188, Fit time=0.508 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(1, 1, 0, 12); AIC=1997.565, BIC=2010.641, Fit time=0.741 seconds
# Total fit time: 4.665 seconds

# %%
model_1.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
mse_1 = ((fc_series_1 - test) ** 2).mean()
rmse_1 =round(np.sqrt(mse_1), 2)
print(rmse_1)
# Out:
# 230220.3

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series_1, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
#(3, 1, 12)
model_2 = pm.auto_arima(train, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=3, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# print(model_1.summary())
fitted_2 = model_2.fit(train)
fc_2, conf_2 = fitted_2.predict(len(test),return_conf_int=True,alpha=0.05)
fc_series_2 = pd.Series(fc_2, index=test.index)
# lower_series_2 = pd.Series(conf_2[:, 0], index=test.index)
# upper_series_2 = pd.Series(conf_2[:, 1], index=test.index)
# Out:
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 1, 1, 12); AIC=2004.252, BIC=2017.278, Fit time=0.485 seconds
# Fit ARIMA: order=(0, 3, 0) seasonal_order=(0, 1, 0, 12); AIC=2084.132, BIC=2089.342, Fit time=0.016 seconds
# Fit ARIMA: order=(1, 3, 0) seasonal_order=(1, 1, 0, 12); AIC=2096.682, BIC=2107.103, Fit time=0.246 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(0, 1, 1, 12); AIC=2000.482, BIC=2010.903, Fit time=0.644 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(1, 1, 1, 12); AIC=1997.728, BIC=2010.754, Fit time=1.412 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(1, 1, 0, 12); AIC=2006.556, BIC=2016.977, Fit time=0.267 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(1, 1, 2, 12); AIC=2004.765, BIC=2020.396, Fit time=2.680 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(0, 1, 0, 12); AIC=1995.419, BIC=2003.234, Fit time=0.155 seconds
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 1, 0, 12); AIC=1995.679, BIC=2006.100, Fit time=0.251 seconds
# Fit ARIMA: order=(0, 3, 2) seasonal_order=(0, 1, 0, 12); AIC=1991.946, BIC=2002.367, Fit time=0.302 seconds
# Fit ARIMA: order=(1, 3, 3) seasonal_order=(0, 1, 0, 12); AIC=1994.337, BIC=2009.968, Fit time=0.483 seconds
# Fit ARIMA: order=(0, 3, 2) seasonal_order=(1, 1, 0, 12); AIC=1993.814, BIC=2006.839, Fit time=0.670 seconds
# Fit ARIMA: order=(0, 3, 2) seasonal_order=(0, 1, 1, 12); AIC=1993.812, BIC=2006.838, Fit time=0.654 seconds
# Fit ARIMA: order=(0, 3, 2) seasonal_order=(1, 1, 1, 12); AIC=1994.714, BIC=2010.345, Fit time=1.152 seconds
# Fit ARIMA: order=(1, 3, 2) seasonal_order=(0, 1, 0, 12); AIC=1999.070, BIC=2012.096, Fit time=0.297 seconds
# Fit ARIMA: order=(0, 3, 3) seasonal_order=(0, 1, 0, 12); AIC=1992.748, BIC=2005.774, Fit time=0.431 seconds
# Total fit time: 10.148 seconds

# %%
len(test)
# Out:
# 29

# %%
test.index
# Out:
# Int64Index([115, 116, 117, 118, 119, 120, 121, 122, 123, 124, 125, 126, 127,
#             128, 129, 130, 131, 132, 133, 134, 135, 136, 137, 138, 139, 140,
#             141, 142, 143],
#            dtype='int64')

# %%
model_2.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
mse_2 = ((fc_series_2 - test) ** 2).mean()
rmse_2 =round(np.sqrt(mse_2), 2)
print(rmse_2)
# Out:
# 49459.73

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series_2, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
ignore_size = int(len(X) * 0.33)
ignore_2 = data['MedianSoldPrice_AllHomes.California'][:ignore_size]
train_2 = data['MedianSoldPrice_AllHomes.California'][ignore_size:].dropna()
forecast = data['MedianSoldPrice_AllHomes.California'][144:174]

# %%
#define the model with (3, 1, 12) and fit the data
model_fc = pm.auto_arima(train_2, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=3, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# print(model_1.summary())
fitted_fc = model_fc.fit(train_2)
fc_fc, conf_fc = fitted_fc.predict(len(forecast),return_conf_int=True,alpha=0.05)
fc_series_fc = pd.Series(fc_fc, index=forecast.index)
# Out:
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 1, 1, 12); AIC=1645.801, BIC=1657.835, Fit time=0.436 seconds
# Fit ARIMA: order=(0, 3, 0) seasonal_order=(0, 1, 0, 12); AIC=1704.523, BIC=1709.337, Fit time=0.011 seconds
# Fit ARIMA: order=(1, 3, 0) seasonal_order=(1, 1, 0, 12); AIC=1712.033, BIC=1721.660, Fit time=0.123 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(0, 1, 1, 12); AIC=1645.629, BIC=1655.256, Fit time=0.258 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(1, 1, 1, 12); AIC=1644.039, BIC=1656.073, Fit time=0.494 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(1, 1, 0, 12); AIC=1645.652, BIC=1655.279, Fit time=0.175 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(1, 1, 2, 12); AIC=1646.008, BIC=1660.448, Fit time=1.615 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(0, 1, 0, 12); AIC=1636.281, BIC=1643.501, Fit time=0.102 seconds
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 1, 0, 12); AIC=1639.997, BIC=1649.624, Fit time=0.200 seconds
# Fit ARIMA: order=(0, 3, 2) seasonal_order=(0, 1, 0, 12); AIC=1637.905, BIC=1647.532, Fit time=0.212 seconds
# Fit ARIMA: order=(1, 3, 2) seasonal_order=(0, 1, 0, 12); AIC=1635.601, BIC=1647.634, Fit time=0.380 seconds
# Fit ARIMA: order=(1, 3, 2) seasonal_order=(1, 1, 0, 12); AIC=1638.338, BIC=1652.778, Fit time=0.605 seconds
# Fit ARIMA: order=(1, 3, 2) seasonal_order=(0, 1, 1, 12); AIC=1637.462, BIC=1651.902, Fit time=1.197 seconds
# Fit ARIMA: order=(1, 3, 2) seasonal_order=(1, 1, 1, 12); AIC=1638.694, BIC=1655.541, Fit time=1.311 seconds
# Fit ARIMA: order=(2, 3, 2) seasonal_order=(0, 1, 0, 12); AIC=1637.756, BIC=1652.196, Fit time=1.858 seconds
# Fit ARIMA: order=(1, 3, 3) seasonal_order=(0, 1, 0, 12); AIC=1635.767, BIC=1650.207, Fit time=1.073 seconds
# Fit ARIMA: order=(2, 3, 3) seasonal_order=(0, 1, 0, 12); AIC=1629.240, BIC=1646.087, Fit time=0.789 seconds
# Fit ARIMA: order=(2, 3, 3) seasonal_order=(1, 1, 0, 12); AIC=1629.495, BIC=1648.748, Fit time=1.358 seconds
# Fit ARIMA: order=(2, 3, 3) seasonal_order=(0, 1, 1, 12); AIC=1629.413, BIC=1648.667, Fit time=0.955 seconds
# Fit ARIMA: order=(2, 3, 3) seasonal_order=(1, 1, 1, 12); AIC=1632.495, BIC=1654.156, Fit time=1.735 seconds
# Fit ARIMA: order=(3, 3, 3) seasonal_order=(0, 1, 0, 12); AIC=1639.211, BIC=1658.465, Fit time=0.883 seconds
# Total fit time: 15.774 seconds

# %%
#forecasting 2016-2017 
fc_fc, conf_fc = fitted_fc.predict(len(forecast),return_conf_int=True, alpha=0.05)
forcast_2016_17 = pd.Series(fc_fc, index=forecast.index)

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.xticks(np.arange(0, 170, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016', '2017', '2018'))
plt.plot(ignore_2, label='ignore')
plt.plot(train_2, label='training')
plt.plot(forcast_2016_17, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
#(2, 2, 12)
model_3 = pm.auto_arima(train, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=2, D=2, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# print(model_1.summary())
fitted_3 = model_3.fit(train)
fc_3, conf_3 = fitted_3.predict(len(test),return_conf_int=True,alpha=0.05)
fc_series_3 = pd.Series(fc_3, index=test.index)
lower_series_3 = pd.Series(conf_3[:, 0], index=test.index)
upper_series_3 = pd.Series(conf_3[:, 1], index=test.index)
# Out:
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(0, 2, 1, 12); AIC=1786.789, BIC=1799.232, Fit time=1.453 seconds
# Fit ARIMA: order=(0, 2, 0) seasonal_order=(0, 2, 0, 12); AIC=1858.671, BIC=1863.649, Fit time=0.025 seconds
# Fit ARIMA: order=(1, 2, 0) seasonal_order=(1, 2, 0, 12); AIC=1861.609, BIC=1871.563, Fit time=0.316 seconds
# Fit ARIMA: order=(0, 2, 1) seasonal_order=(0, 2, 1, 12); AIC=1787.595, BIC=1797.549, Fit time=1.435 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(1, 2, 1, 12); AIC=1809.877, BIC=1824.809, Fit time=2.241 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(0, 2, 0, 12); AIC=1842.755, BIC=1852.709, Fit time=0.646 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(0, 2, 2, 12); AIC=1810.096, BIC=1825.027, Fit time=2.956 seconds
# Fit ARIMA: order=(1, 2, 1) seasonal_order=(1, 2, 2, 12); AIC=1813.069, BIC=1830.489, Fit time=3.313 seconds
# Fit ARIMA: order=(2, 2, 1) seasonal_order=(0, 2, 1, 12); AIC=1784.096, BIC=1799.028, Fit time=1.827 seconds
# Fit ARIMA: order=(2, 2, 0) seasonal_order=(0, 2, 1, 12); AIC=1789.539, BIC=1801.983, Fit time=0.946 seconds
# Fit ARIMA: order=(2, 2, 2) seasonal_order=(0, 2, 1, 12); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 2, 0) seasonal_order=(0, 2, 1, 12); AIC=1788.414, BIC=1798.368, Fit time=1.302 seconds
# Fit ARIMA: order=(3, 2, 2) seasonal_order=(0, 2, 1, 12); AIC=1804.105, BIC=1824.014, Fit time=2.896 seconds
# Fit ARIMA: order=(2, 2, 1) seasonal_order=(1, 2, 1, 12); AIC=1813.300, BIC=1830.720, Fit time=0.574 seconds
# Fit ARIMA: order=(2, 2, 1) seasonal_order=(0, 2, 0, 12); AIC=1844.698, BIC=1857.141, Fit time=0.653 seconds
# Fit ARIMA: order=(2, 2, 1) seasonal_order=(0, 2, 2, 12); AIC=1813.064, BIC=1830.484, Fit time=1.943 seconds
# Fit ARIMA: order=(2, 2, 1) seasonal_order=(1, 2, 2, 12); AIC=1815.085, BIC=1834.994, Fit time=3.578 seconds
# Fit ARIMA: order=(3, 2, 1) seasonal_order=(0, 2, 1, 12); AIC=1811.894, BIC=1829.314, Fit time=1.778 seconds
# Total fit time: 29.507 seconds

# %%
model_3.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
mse_3 = ((fc_series_3 - test) ** 2).mean()
rmse_3 =round(np.sqrt(mse_3), 2)
print(rmse_3)
# Out:
# 248472.53

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.xticks(np.arange(0, 163, step=12), ('2004', '2005', '2006', 
                                        '2007', '2008', '2009', 
                                        '2010', '2011', '2012', 
                                        '2013', '2014', '2015', '2016'))
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series_3, label='forecast')
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
#(3, 2, 12)
model_4 = pm.auto_arima(train, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=12,
                           start_P=0, seasonal=True,
                           d=3, D=2, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
# print(model_1.summary())
fitted_4 = model_4.fit(train)
fc_4, conf_4 = fitted_4.predict(len(test),return_conf_int=True,alpha=0.05)
fc_series_4 = pd.Series(fc_4, index=test.index)
lower_series_4 = pd.Series(conf_4[:, 0], index=test.index)
upper_series_4 = pd.Series(conf_4[:, 1], index=test.index)
# Out:
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 2, 1, 12); AIC=1782.229, BIC=1794.616, Fit time=1.959 seconds
# Fit ARIMA: order=(0, 3, 0) seasonal_order=(0, 2, 0, 12); AIC=1926.847, BIC=1931.802, Fit time=0.024 seconds
# Fit ARIMA: order=(1, 3, 0) seasonal_order=(1, 2, 0, 12); AIC=1931.408, BIC=1941.318, Fit time=0.317 seconds
# Fit ARIMA: order=(0, 3, 1) seasonal_order=(0, 2, 1, 12); AIC=1784.323, BIC=1794.232, Fit time=1.437 seconds
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(1, 2, 1, 12); AIC=1783.448, BIC=1798.312, Fit time=1.954 seconds
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 2, 0, 12); AIC=1832.497, BIC=1842.406, Fit time=0.557 seconds
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(0, 2, 2, 12); AIC=1815.540, BIC=1830.404, Fit time=3.820 seconds
# Fit ARIMA: order=(1, 3, 1) seasonal_order=(1, 2, 2, 12); AIC=1820.286, BIC=1837.627, Fit time=4.032 seconds
# Fit ARIMA: order=(2, 3, 1) seasonal_order=(0, 2, 1, 12); AIC=1814.897, BIC=1829.761, Fit time=2.319 seconds
# Fit ARIMA: order=(1, 3, 0) seasonal_order=(0, 2, 1, 12); AIC=1821.782, BIC=1831.692, Fit time=1.378 seconds
# Fit ARIMA: order=(1, 3, 2) seasonal_order=(0, 2, 1, 12); AIC=1814.901, BIC=1829.765, Fit time=3.429 seconds
# Fit ARIMA: order=(0, 3, 0) seasonal_order=(0, 2, 1, 12); AIC=1859.698, BIC=1867.130, Fit time=1.068 seconds
# Fit ARIMA: order=(2, 3, 2) seasonal_order=(0, 2, 1, 12); AIC=1811.589, BIC=1828.931, Fit time=2.593 seconds
# Total fit time: 24.892 seconds

# %%
model_4.plot_diagnostics(figsize=(10,8))
plt.show()

# %%
mse_4 = ((fc_series_4 - test) ** 2).mean()
rmse_4 =round(np.sqrt(mse_4), 2)
print(rmse_4)
# Out:
# 89461.25
